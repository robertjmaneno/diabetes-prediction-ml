# %% [markdown]
# # Data Exploration and Preprocessing
#
# In this section, we will explore the dataset to understand its structure, identify patterns, and detect any missing or inconsistent values.
# We will also preprocess the data to make it suitable for machine learning by handling missing values, encoding categorical variables,
# and scaling numerical features. This step will ensures that the data is clean, consistent, and ready for model training.

# %% [markdown]
# # Import the necessary libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Load the dataset into a pandas DataFrame

# %%
data = pd.read_csv('../data/raw/diabetes.csv')

# %% [markdown]
# # Preview the dataset

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Obtain the length(rows) and the width(columns) of the dataset

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# # Inspect basic information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %% [markdown]
# # Check for missing values

# %%
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Check data distribution and outliers

# %%
plt.close('all')
data.hist(bins=20, figsize=(10, 8))
plt.show()

# %%
data.head(20)
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
data.tail(20)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 748            3      187             70             22      200  36.4
# 749            6      162             62              0        0  24.3
# 750            4      136             70              0        0  31.2
# 751            1      121             78             39       74  39.0
# 752            3      108             62             24        0  26.0
# 753            0      181             88             44      510  43.3
# 754            8      154             78             32        0  32.4
# 755            1      128             88             39      110  36.5
# 756            7      137             90             41        0  32.0
# 757            0      123             72              0        0  36.3
# 758            1      106             76              0        0  37.5
# 759            6      190             92              0        0  35.5
# ...

# %% [markdown]
# # Select all the features

# %%
featured_data = data.iloc[:, :-1]
print(featured_data)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %% [markdown]
# # Count total number of rows

# %%
num_cases = data.shape[0]
print(f'Total number of rows: {num_cases}')
# Out:
# Total number of rows: 768

# %% [markdown]
# # Number and percent of '0' for each feature

# %%
number_of_zeros = (featured_data[:] == 0).sum()
print(number_of_zeros)

percentage_of_zeros = (number_of_zeros / num_cases) * 100
print(percentage_of_zeros)
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# dtype: int64
# Pregnancies                 14.453125
# Glucose                      0.651042
# BloodPressure                4.557292
# SkinThickness               29.557292
# Insulin                     48.697917
# BMI                          1.432292
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# dtype: float64

# %% [markdown]
# # Look for correlations

# %%
corrM = data.corr()
corrM.style.background_gradient().format(precision=3)
# Out:
# <style type="text/css">
# #T_642bf_row0_col0, #T_642bf_row1_col1, #T_642bf_row2_col2, #T_642bf_row3_col3, #T_642bf_row4_col4, #T_642bf_row5_col5, #T_642bf_row6_col6, #T_642bf_row7_col7, #T_642bf_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_642bf_row0_col1 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_642bf_row0_col2, #T_642bf_row2_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_642bf_row0_col3, #T_642bf_row7_col4 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_642bf_row0_col4, #T_642bf_row0_col5, #T_642bf_row0_col6, #T_642bf_row2_col8, #T_642bf_row3_col0, #T_642bf_row3_col1, #T_642bf_row3_col7, #T_642bf_row6_col2, #T_642bf_row7_col3 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_642bf_row0_col7 {
#   background-color: #4697c4;
#   color: #f1f1f1;
# }
# #T_642bf_row0_col8, #T_642bf_row1_col6 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_642bf_row1_col0 {
# ...
